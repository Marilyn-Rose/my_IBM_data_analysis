# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/user/Desktop/my_paypal_creditcard (1).csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
# lET'S EXPLORE THE DATA:

# %%
data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
data.describe(include = 'all')
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
data[['Time']]
# Out:
#             Time
# 0            0.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            2.0
# ...          ...
# 284802  172786.0
# 284803  172787.0
# 284804  172788.0
# 284805  172788.0
# 284806  172792.0
#
# [284807 rows x 1 columns]

# %%
# This will give the actual time from the 'Time' variable that was given:

#from datetime import datetime, timedelta

#start_time = datetime.strptime('2013-01-01 00:00:00', '%Y-%m-%d %H:%M:%S')

#data['ActualTime'] = data['Time'].apply(lambda x: start_time + timedelta(seconds=x))

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
missing_values = data.isnull()

# %%
print(data['Class'].value_counts()) # checks the distribution of the class
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
sns.countplot(x='Class', data = data)
plt.title('Class Distribution')
plt.show()

# %%
for column in missing_values.columns.values.tolist():
    print(column)
    print(missing_values[column].value_counts())
    print("")
# Out:
# Time
# Time
# False    284807
# Name: count, dtype: int64
#
# V1
# V1
# False    284807
# Name: count, dtype: int64
#
# V2
# V2
# False    284807
# Name: count, dtype: int64
#
# V3
# V3
# False    284807
# Name: count, dtype: int64
#
# V4
# V4
# False    284807
# Name: count, dtype: int64
#
# V5
# V5
# False    284807
# Name: count, dtype: int64
#
# V6
# V6
# False    284807
# Name: count, dtype: int64
#
# V7
# V7
# False    284807
# Name: count, dtype: int64
#
# V8
# V8
# False    284807
# Name: count, dtype: int64
#
# V9
# V9
# False    284807
# Name: count, dtype: int64
#
# V10
# V10
# False    284807
# Name: count, dtype: int64
#
# V11
# V11
# False    284807
# Name: count, dtype: int64
#
# V12
# V12
# False    284807
# Name: count, dtype: int64
#
# V13
# V13
# False    284807
# Name: count, dtype: int64
#
# V14
# V14
# False    284807
# Name: count, dtype: int64
#
# V15
# V15
# False    284807
# Name: count, dtype: int64
#
# V16
# V16
# False    284807
# ...

# %%
# DATA PREPROCESSING

# %%
# Splitting the dataset into test set of 20% and training set of 80%

from sklearn.model_selection import train_test_split

x_data = data.drop('Class', axis=1)
y_data = data['Class']

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42, stratify=y_data)

# %%
# Creating a model StandardScaler

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])

# %%
scaler
# Out:
# StandardScaler()

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
x_train_res, y_train_res = smote.fit_resample(x_train, y_train)

# %%
# MODEL SELECION AND TRAINING

# %%
from sklearn.feature_selection import SelectKBest, f_classif

selector = SelectKBest(score_func = f_classif, k = 10)
X_selected = selector.fit_transform(x_data, y_data)

selected_features = x_data.columns[selector.get_support()]
print(selected_features)
# Out:
# Index(['V3', 'V4', 'V7', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17', 'V18'], dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier

RFmodel = RandomForestClassifier(n_estimators = 100, random_state=42, n_jobs = -1)

RFmodel.fit(x_train_res, y_train_res)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
# MODEL EVALUATION

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, precision_recall_curve, auc

try:
    y_pred = RFmodel.predict(x_test) 
    y_pred_proba = RFmodel.predict_proba(x_test)[:, 1] 
    
    print('Confusion Matrix:')
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print(f'ROC-AUC Score: {roc_auc_score(y_test, y_pred_proba):.2f}')
    
    precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
    auc_pr = auc(recall, precision)
except AttributeError as e:
    print(f'AttributeErro: {e}')

except Exception as e:
    print(f'Error: {e}')
# Out:
# Confusion Matrix:
# [[56848    16]
#  [   17    81]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.84      0.83      0.83        98
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.91      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC-AUC Score: 0.96

# %%
plt.figure()
plt.plot(recall, precision, label=f'AUC-PR = {auc_pr:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()

# %%
#from imblearn.over_sampling import SMOTE

#smote = SMOTE(random_state=42)
#x_train_res, y_train_res = smote.fit_resample(x_train, y_train)

# %%
# MODEL SERIALIZATION:

# %%
import joblib

joblib.dump(RFmodel, 'Credit_card_fraud_detection.pkl')
# Out:
# ['Credit_card_fraud_detection.pkl']

# %%
results_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

fraudulent_counts = results_df['Actual'].value_counts()

plt.figure(figsize = (6,4))
sns.barplot(x=fraudulent_counts.index, y=fraudulent_counts.values)
plt.title('Number of Fraudulent Activities by Class')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks([0, 1], ['Non-Fraudulent (0)', 'Fraudulent (1)'])
plt.show()
